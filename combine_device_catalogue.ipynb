# %%
import pandas as pd

# %%
d2015=pd.read_csv('DEVICE2015.txt',sep='|',encoding='latin1',on_bad_lines='skip')

#when encountering lines with incorrect column numbers, skip
# Out:
# /var/folders/4l/g3wrn7zd5dz5cnt59_md7ldm0000gn/T/ipykernel_56776/74819253.py:1: DtypeWarning: Columns (32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   d2015=pd.read_csv('DEVICE2015.txt',sep='|',encoding='latin1',on_bad_lines='skip')

# %%
dfs = {} #Save all years inside one dictionary
def load_device_year(year):
    path = f"DEVICE{year}.txt"
    dfs[f"d{year}"] = pd.read_csv(path,sep='|',encoding='latin1',on_bad_lines='skip')
    #when encountering lines with incorrect column numbers, skip

# %%
for year in range(2015,2026):
    load_device_year(year)
# Out:
# /var/folders/4l/g3wrn7zd5dz5cnt59_md7ldm0000gn/T/ipykernel_56776/2884843464.py:4: DtypeWarning: Columns (32,33) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs[f"d{year}"] = pd.read_csv(path,sep='|',encoding='latin1',on_bad_lines='skip')
# /var/folders/4l/g3wrn7zd5dz5cnt59_md7ldm0000gn/T/ipykernel_56776/2884843464.py:4: DtypeWarning: Columns (0,1,2,4,5,6,17,25,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs[f"d{year}"] = pd.read_csv(path,sep='|',encoding='latin1',on_bad_lines='skip')
# /var/folders/4l/g3wrn7zd5dz5cnt59_md7ldm0000gn/T/ipykernel_56776/2884843464.py:4: DtypeWarning: Columns (0,1,2,3,4,5,6,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs[f"d{year}"] = pd.read_csv(path,sep='|',encoding='latin1',on_bad_lines='skip')
# ...

# %%
dfs["d2015"].head()
# Out:
#    MDR_REPORT_KEY  DEVICE_EVENT_KEY  IMPLANT_FLAG  DATE_REMOVED_FLAG  \
# 0         2296019               NaN           NaN                NaN
# 1         2686192               NaN           NaN                NaN
# 2         2893201               NaN           NaN                NaN
# 3         4068041               NaN           NaN                NaN
# 4         4080233               NaN           NaN                NaN
#
#    DEVICE_SEQUENCE_NO  IMPLANT_DATE_YEAR  DATE_REMOVED_YEAR  \
# 0              451705             2008.0             2010.0
# 1               20222             2010.0             2010.0
# 2              309162                NaN                NaN
# 3              110085             2006.0             2014.0
# 4              271555                NaN                NaN
#
#   SERVICED_BY_3RD_PARTY_FLAG DATE_RECEIVED  \
# 0                        NaN    2015/07/13
# 1                        NaN    2015/01/09
# 2                        NaN    2015/05/11
# ...

# %%
combined_df = pd.concat(dfs.values(), ignore_index=True)

# %%
combined_df.head()
# Out:
#   MDR_REPORT_KEY DEVICE_EVENT_KEY IMPLANT_FLAG DATE_REMOVED_FLAG  \
# 0        2296019              NaN          NaN               NaN
# 1        2686192              NaN          NaN               NaN
# 2        2893201              NaN          NaN               NaN
# 3        4068041              NaN          NaN               NaN
# 4        4080233              NaN          NaN               NaN
#
#   DEVICE_SEQUENCE_NO IMPLANT_DATE_YEAR DATE_REMOVED_YEAR  \
# 0             451705            2008.0            2010.0
# 1              20222            2010.0            2010.0
# 2             309162               NaN               NaN
# 3             110085            2006.0            2014.0
# 4             271555               NaN               NaN
#
#   SERVICED_BY_3RD_PARTY_FLAG DATE_RECEIVED  \
# 0                        NaN    2015/07/13
# 1                        NaN    2015/01/09
# 2                        NaN    2015/05/11
# 3                        NaN    2015/02/13
# ...

# %%
#Decribe Dataset
combined_df.describe()
# Out:
#        MDR_REPORT_KEY              DEVICE_EVENT_KEY            IMPLANT_FLAG  \
# count        19414644                           167                     175
# unique       19380178                            43                      29
# top        VIDEOSCOPE  SMALL  INTESTINAL VIDEOSCOPE  AIZU OLYMPUS CO., LTD.
# freq               56                            46                      39
#
#         DATE_REMOVED_FLAG  DEVICE_SEQUENCE_NO  IMPLANT_DATE_YEAR  \
# count                  99            19414493          5966462.0
# unique                  6             3114215              167.0
# top     3-1-1 NIIDERAKITA               24193             2024.0
# freq                   39                  35           570962.0
#
#         DATE_REMOVED_YEAR SERVICED_BY_3RD_PARTY_FLAG DATE_RECEIVED  \
# count           4659963.0                    9352705      19414513
# unique              113.0                         11          3975
# ...

# %%
#Check columns with NAN
combined_df.isna().any()
# Out:
# MDR_REPORT_KEY                    False
# DEVICE_EVENT_KEY                   True
# IMPLANT_FLAG                       True
# DATE_REMOVED_FLAG                  True
# DEVICE_SEQUENCE_NO                 True
# IMPLANT_DATE_YEAR                  True
# DATE_REMOVED_YEAR                  True
# SERVICED_BY_3RD_PARTY_FLAG         True
# DATE_RECEIVED                      True
# BRAND_NAME                         True
# GENERIC_NAME                       True
# MANUFACTURER_D_NAME                True
# MANUFACTURER_D_ADDRESS_1           True
# MANUFACTURER_D_ADDRESS_2           True
# MANUFACTURER_D_CITY                True
# MANUFACTURER_D_STATE_CODE          True
# MANUFACTURER_D_ZIP_CODE            True
# MANUFACTURER_D_ZIP_CODE_EXT        True
# MANUFACTURER_D_COUNTRY_CODE        True
# MANUFACTURER_D_POSTAL_CODE         True
# DEVICE_OPERATOR                    True
# EXPIRATION_DATE_OF_DEVICE          True
# MODEL_NUMBER                       True
# ...

# %%
#Check numbers of NAN per Column
combined_df.isna().sum()
# Out:
# MDR_REPORT_KEY                           0
# DEVICE_EVENT_KEY                  19414477
# IMPLANT_FLAG                      19414469
# DATE_REMOVED_FLAG                 19414545
# DEVICE_SEQUENCE_NO                     151
# IMPLANT_DATE_YEAR                 13448182
# DATE_REMOVED_YEAR                 14754681
# SERVICED_BY_3RD_PARTY_FLAG        10061939
# DATE_RECEIVED                          131
# BRAND_NAME                           94675
# GENERIC_NAME                         75404
# MANUFACTURER_D_NAME                  93540
# MANUFACTURER_D_ADDRESS_1            590796
# MANUFACTURER_D_ADDRESS_2          17553798
# MANUFACTURER_D_CITY                 390870
# MANUFACTURER_D_STATE_CODE          6975186
# MANUFACTURER_D_ZIP_CODE            1318761
# MANUFACTURER_D_ZIP_CODE_EXT       13951641
# MANUFACTURER_D_COUNTRY_CODE        1710497
# MANUFACTURER_D_POSTAL_CODE         1318627
# DEVICE_OPERATOR                    1054088
# EXPIRATION_DATE_OF_DEVICE         13582861
# ...
